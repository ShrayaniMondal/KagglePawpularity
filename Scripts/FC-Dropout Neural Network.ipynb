# %%
from google.colab import drive
drive.mount('/content/drive')
import sys
sys.path.append("/content/drive/My Drive/589MiniProject/")
# %cd /content/drive/My Drive/589MiniProject/
# Out:
# Mounted at /content/drive
# /content/drive/.shortcut-targets-by-id/1yyh1nEBAISidzfrj3Aql57NwD7xFpa20/589MiniProject

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torchsummary import summary
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader, TensorDataset
import matplotlib.pyplot as plt
import os
import warnings
import pandas as pd
warnings.filterwarnings('ignore')
from sklearn.metrics import mean_squared_error
from sklearn import preprocessing

# %%
USE_GPU = True

dtype = torch.float32 # we will be using float throughout this tutorial

if USE_GPU and torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

# Constant to control how frequently we print train loss
print_every = 75

print('using device:', device)
# Out:
# using device: cpu

# %%
# !pip install img2vec_pytorch
# Out:
# Collecting img2vec_pytorch
#   Downloading img2vec_pytorch-0.2.5.tar.gz (4.2 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from img2vec_pytorch) (1.10.0+cu111)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from img2vec_pytorch) (0.11.1+cu111)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from img2vec_pytorch) (1.19.5)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->img2vec_pytorch) (3.10.0.2)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->img2vec_pytorch) (7.1.2)
# Building wheels for collected packages: img2vec-pytorch
#   Building wheel for img2vec-pytorch (setup.py) ... done
#   Created wheel for img2vec-pytorch: filename=img2vec_pytorch-0.2.5-py3-none-any.whl size=4345 sha256=128b84d02053f285bab142879f89e8eb74022a3b7922291c85292410ac2ac2fa
#   Stored in directory: /root/.cache/pip/wheels/07/4d/bf/9de03c3e76c20899b69498f90624ec499c7c67dd13f183f4e9
# Successfully built img2vec-pytorch
# Installing collected packages: img2vec-pytorch
# Successfully installed img2vec-pytorch-0.2.5

# %%
from img2vec_pytorch import Img2Vec
from PIL import Image

# # Initialize Img2Vec with GPU
# img2vec = Img2Vec(torch.cuda.is_available())

# # Read in an image (rgb format)
# img = Image.open('test.jpg')
# # Get a vector from img2vec, returned as a torch FloatTensor
# vec = img2vec.get_vec(img, tensor=True)
# # Or submit a list
# vectors = img2vec.get_vec(list_of_PIL_images)
def imgVec(folder='Train'):
  dataPath = "Data/" + folder + "/"
  metadataPath = "./Data/MetaData/" + folder.lower() + ".csv"
  df = pd.read_csv(metadataPath)
  # df['img_path'] = os.getcwd() + '/Data/' + folder + "/" + df['Id'] + '.jpg'
  df['img_path'] = './Data/' + folder + "/" + df['Id'] + '.jpg'
  img2vec = Img2Vec(cuda=(torch.cuda.is_available()))  
  img_vecs = []
  for idx, row in df.iterrows():
    # print(path + '/Data/' + 'Test/' + row['Id'] + '.jpg')
    img = Image.open(row["img_path"])
    vec = img2vec.get_vec(img)
    img_vecs.append(vec)

  df['feature_vector'] = img_vecs
  return df

# %%
train_df = imgVec('Train')
train_df.reset_index(inplace=True)
col_names = ["feat"+str(i) for i in range(len(train_df.iloc[0]["feature_vector"]))]
train_df[col_names] = pd.DataFrame(train_df.feature_vector.tolist(), index= train_df.index)
train_df.drop(columns = ["Id","img_path","feature_vector"], inplace=True)


valid_df = imgVec('Valid')
valid_df.reset_index(inplace=True)
col_names = ["feat"+str(i) for i in range(len(valid_df.iloc[0]["feature_vector"]))]
valid_df[col_names] = pd.DataFrame(valid_df.feature_vector.tolist(), index= valid_df.index)
valid_df.drop(columns = ["Id","img_path","feature_vector"], inplace=True)

test_df = imgVec('Test')
test_df.reset_index(inplace=True)
col_names = ["feat"+str(i) for i in range(len(test_df.iloc[0]["feature_vector"]))]
test_df[col_names] = pd.DataFrame(test_df.feature_vector.tolist(), index= test_df.index)
test_df.drop(columns = ["Id","img_path","feature_vector"], inplace=True)

print("Train ...")
print(train_df.head())

print("Valid ...")
print(valid_df.head())

print("Test ...")
print(test_df.head())
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
#   0%|          | 0.00/44.7M [00:00<?, ?B/s]
# Train ...
#    index  Subject Focus  Eyes  Face  ...   feat508   feat509   feat510   feat511
# 0      0              0     1     1  ...  1.552251  0.729470  1.408372  1.468240
# 1      1              0     1     1  ...  0.841265  1.340379  2.015083  0.379474
# 2      2              0     1     1  ...  0.902725  0.322946  1.937619  0.461102
# 3      3              0     1     1  ...  1.789118  1.036564  0.068066  0.716284
# 4      4              0     1     1  ...  3.102909  1.097454  0.581716  0.273106
#
# [5 rows x 526 columns]
# Valid ...
#    index  Subject Focus  Eyes  Face  ...   feat508   feat509   feat510   feat511
# 0      0              0     0     1  ...  1.847430  0.734269  0.584828  1.115096
# 1      1              0     1     1  ...  1.499832  2.500482  0.277388  0.397272
# 2      2              0     1     1  ...  0.401953  0.236270  0.914187  0.319195
# 3      3              0     1     1  ...  2.246782  1.693573  0.013458  1.673211
# 4      4              0     1     1  ...  2.828182  1.301023  0.482935  0.697950
#
# [5 rows x 526 columns]
# Test ...
#    index  Subject Focus  Eyes  Face  ...   feat508   feat509   feat510   feat511
# 0      0              0     1     1  ...  1.422815  0.811384  0.970109  1.686729
# 1      1              0     1     1  ...  2.874696  1.433165  0.064450  1.330669
# 2      2              0     1     1  ...  1.328919  1.550340  2.265544  0.047985
# 3      3              0     0     1  ...  0.034773  1.261934  1.168133  0.213855
# 4      4              0     0     0  ...  0.352993  0.132436  0.413281  0.665387
#
# [5 rows x 526 columns]

# %%
train_y, valid_y, test_y = train_df['Pawpularity'], valid_df['Pawpularity'], test_df['Pawpularity']
train_X = train_df.drop(columns=['Pawpularity'])
train_X = preprocessing.StandardScaler().fit_transform(train_X)
valid_X = valid_df.drop(columns=['Pawpularity'])
valid_X = preprocessing.StandardScaler().fit_transform(valid_X)
test_X = test_df.drop(columns=['Pawpularity'])
test_X = preprocessing.StandardScaler().fit_transform(test_X)

# %%
# convert a df to tensor to be used in pytorch
def df_to_tensor(df):
    # return torch.from_numpy(df.values).type(dtype).to(device)
    # return torch.from_numpy(df.to_numpy()).type(dtype).to(device)
    return torch.from_numpy(df).type(dtype).to(device)

# %%
def df_to_tensor_labels(df):
    return torch.from_numpy(df.to_numpy()).type(dtype).to(device)

# %%
torch_train_X = df_to_tensor(train_X)
torch_train_y = df_to_tensor_labels(train_y)
train_ds = TensorDataset(torch_train_X, torch_train_y)

torch_valid_X = df_to_tensor(valid_X)
torch_valid_y = df_to_tensor_labels(valid_y)
valid_ds = TensorDataset(torch_valid_X, torch_valid_y)

torch_test_X = df_to_tensor(test_X)
torch_test_y = df_to_tensor_labels(test_y)
test_ds = TensorDataset(torch_test_X, torch_test_y)

# %%
train_loader = DataLoader(train_ds, batch_size=64,shuffle=True,num_workers=2)
valid_loader = DataLoader(valid_ds, batch_size=64,shuffle=True,num_workers=2)
test_loader = DataLoader(test_ds, batch_size=64,shuffle=True,num_workers=2)

# %%
print(train_loader)
# Out:
# <torch.utils.data.dataloader.DataLoader object at 0x7fd31ffaa0d0>

# %%
loss_history = []

# %%
def check_mse(loader,model):
  print('calculating mse for valid set')
  model.eval()
  valid_mse = 0.0
  num_samples = 0
  with torch.no_grad():
      for data, target in loader:
          data, target = data.to(device=device,dtype=dtype), target.to(device=device,dtype=dtype)
          output = model(data)
          num_samples += len(output)
          valid_mse += mean_squared_error(target,output)

  return valid_mse

# %%
def train(model, optimizer, epoch=1):
    model.train()
    best_mse = float('inf')
    for e in range(epoch):
      for batch_idx, (data, target) in enumerate(train_loader):
          data, target = data.to(device=device,dtype=dtype), target.to(device=device,dtype=dtype)
          optimizer.zero_grad()
          output = model(data)
          loss = F.mse_loss(output, target)
          loss.backward()
          optimizer.step()

          torch.cuda.empty_cache()
          if batch_idx % 100 == 0:
              # Print loss every 100 batch
              print('Train Epoch: {}\tLoss: {:.6f}'.format(
                  e, loss.item()))
              valid_mse = check_mse(valid_loader,model)
              print('valid mse:',valid_mse)
              if valid_mse < best_mse:
                best_mse = valid_mse
                torch.save(model.state_dict(), "./Models/FCNN_BN.pt")
              torch.cuda.empty_cache()

# %%
input_dim = train_X.shape[1]
model = nn.Sequential(
    nn.Linear(input_dim,300,bias=True),
    nn.SiLU(),
    nn.Dropout(p=0.5),
    nn.Linear(300,150,bias=True),
    nn.SiLU(),
    nn.Dropout(p=0.5),
    nn.Linear(150,1,bias=True)
)

# %%
optimizer = optim.Adam(model.parameters(),lr=0.0001, betas=(0.9, 0.999), eps=1e-08, weight_decay=0, amsgrad=False)
lr_scheduler = optim.lr_scheduler.StepLR(optimizer,step_size=7,gamma=0.1)
torch.cuda.empty_cache()
train(model,optimizer,epoch=150)
# Out:
# Train Epoch: 0	Loss: 2264.311523
# calculating mse for valid set
# valid mse: 57230.015869140625
# Train Epoch: 0	Loss: 1372.967285
# calculating mse for valid set
# valid mse: 49346.827392578125
# Train Epoch: 1	Loss: 1689.456787
# calculating mse for valid set
# valid mse: 46989.11682128906
# Train Epoch: 1	Loss: 668.882751
# calculating mse for valid set
# valid mse: 20750.07354736328
# Train Epoch: 2	Loss: 454.158905
# calculating mse for valid set
# valid mse: 20169.961181640625
# Train Epoch: 2	Loss: 428.836365
# calculating mse for valid set
# valid mse: 16598.16064453125
# Train Epoch: 3	Loss: 553.245605
# calculating mse for valid set
# valid mse: 16446.120544433594
# Train Epoch: 3	Loss: 512.638123
# calculating mse for valid set
# valid mse: 15751.380508422852
# Train Epoch: 4	Loss: 469.772644
# calculating mse for valid set
# valid mse: 15695.230499267578
# Train Epoch: 4	Loss: 427.517914
# calculating mse for valid set
# valid mse: 15428.517333984375
# Train Epoch: 5	Loss: 546.747742
# calculating mse for valid set
# valid mse: 15366.047546386719
# Train Epoch: 5	Loss: 285.841064
# calculating mse for valid set
# valid mse: 15117.748443603516
# Train Epoch: 6	Loss: 676.555176
# calculating mse for valid set
# valid mse: 15119.200897216797
# Train Epoch: 6	Loss: 394.372864
# calculating mse for valid set
# valid mse: 14921.588745117188
# Train Epoch: 7	Loss: 258.744293
# calculating mse for valid set
# Train Epoch: 135	Loss: 557.932983
# calculating mse for valid set
# valid mse: 13419.39485168457
# Train Epoch: 136	Loss: 368.212708
# calculating mse for valid set
# valid mse: 13410.5556640625
# Train Epoch: 136	Loss: 393.626556
# calculating mse for valid set
# valid mse: 13421.466247558594
# Train Epoch: 137	Loss: 394.447205
# calculating mse for valid set
# valid mse: 13435.56526184082
# Train Epoch: 137	Loss: 489.614960
# calculating mse for valid set
# valid mse: 13426.544189453125
# Train Epoch: 138	Loss: 475.253906
# calculating mse for valid set
# valid mse: 13466.335845947266
# Train Epoch: 138	Loss: 413.931580
# calculating mse for valid set
# valid mse: 13404.931610107422
# Train Epoch: 139	Loss: 410.546326
# calculating mse for valid set
# valid mse: 13476.28939819336
# Train Epoch: 139	Loss: 353.525757
# calculating mse for valid set
# valid mse: 13462.0546875
# Train Epoch: 140	Loss: 463.434143
# calculating mse for valid set
# valid mse: 13436.724151611328
# Train Epoch: 140	Loss: 234.165161
# calculating mse for valid set
# valid mse: 13464.641387939453
# Train Epoch: 141	Loss: 543.083862
# calculating mse for valid set
# valid mse: 13402.504913330078
# Train Epoch: 141	Loss: 454.630798
# calculating mse for valid set
# valid mse: 13484.56396484375
# Train Epoch: 142	Loss: 364.521057
# calculating mse for valid set
# valid mse: 13477.44482421875
# Train Epoch: 142	Loss: 438.442230
# calculating mse for valid set
# valid mse: 13448.473571777344
# Train Epoch: 143	Loss: 610.291016
# calculating mse for valid set
# valid mse: 13538.610000610352
# Train Epoch: 143	Loss: 557.439819
# calculating mse for valid set
# valid mse: 13393.409729003906
# Train Epoch: 144	Loss: 353.838104
# calculating mse for valid set
# valid mse: 13430.08853149414
# Train Epoch: 144	Loss: 340.598358
# calculating mse for valid set
# valid mse: 13438.009521484375
# Train Epoch: 145	Loss: 539.543518
# calculating mse for valid set
# valid mse: 13491.500701904297
# Train Epoch: 145	Loss: 247.073608
# calculating mse for valid set
# valid mse: 13417.628326416016
# Train Epoch: 146	Loss: 398.898895
# calculating mse for valid set
# valid mse: 13451.074005126953
# Train Epoch: 146	Loss: 385.375031
# calculating mse for valid set
# valid mse: 13414.8056640625
# Train Epoch: 147	Loss: 399.622162
# calculating mse for valid set
# valid mse: 13392.926391601562
# Train Epoch: 147	Loss: 471.007477
# calculating mse for valid set
# valid mse: 13414.385131835938
# Train Epoch: 148	Loss: 299.293213
# calculating mse for valid set
# valid mse: 13494.601318359375
# Train Epoch: 148	Loss: 461.167877
# calculating mse for valid set
# valid mse: 13415.639556884766
# Train Epoch: 149	Loss: 361.578674
# calculating mse for valid set
# valid mse: 13375.964233398438
# Train Epoch: 149	Loss: 403.569214
# calculating mse for valid set
# valid mse: 13476.413452148438

# %%
model.load_state_dict(torch.load("./Models/FCNN_BN.pt"))
test_mse = check_mse(test_loader,model)
print('Test MSE:', test_mse)
print('Test RMSE:',np.sqrt(test_mse))
# Out:
# calculating mse for valid set
# Test MSE: 6674.116363525391
# Test RMSE: 81.69526524545587
